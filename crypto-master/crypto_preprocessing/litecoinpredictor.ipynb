# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", font_scale=1.5)
# %matplotlib inline
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
from numpy import array
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from pandas.tseries.offsets import DateOffset
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("C:\\Users\\arjun\\Desktop\\allprices\\crypto-markets.csv", parse_dates=["date"], index_col="date")
df.shape
# Out:
# (942297, 12)

# %%
df = df[df.slug == "litecoin"][['close']]

# %%
df.head()
# Out:
#             close
# date
# 2013-04-28   4.35
# 2013-04-29   4.38
# 2013-04-30   4.30
# 2013-05-01   3.80
# 2013-05-02   3.37

# %%
train = df

# %%
train=df[:1900]

# %%
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)

# %%
n_input = 50
n_features = 1

# %%
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
generator

# %%
model = Sequential()
model.add(LSTM(units=30, return_sequences= True, input_shape=(n_input,n_features)))
model.add(LSTM(units=30, return_sequences=True))
model.add(LSTM(units=30))
model.add(Dense(units=1))
print(model.summary())

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 50, 30)            3840
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 30)            7320
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30)                7320
# _________________________________________________________________
# dense (Dense)                (None, 1)                 31
# ...
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 124s 401ms/step - loss: 0.0077
# Epoch 2/10
# 309/309 [==============================] - 66s 215ms/step - loss: 0.00261s - loss:
# Epoch 3/10
# 309/309 [==============================] - 59s 190ms/step - loss: 0.0031
# Epoch 4/10
# 309/309 [==============================] - ETA: 0s - loss: 0.002 - 71s 230ms/step - loss: 0.0020
# Epoch 5/10
# 309/309 [==============================] - 67s 215ms/step - loss: 0.0019
# Epoch 6/10
# 309/309 [==============================] - 66s 213ms/step - loss: 0.0015
# Epoch 7/10
# 309/309 [==============================] - 76s 246ms/step - loss: 0.0013
# Epoch 8/10
# 309/309 [==============================] - 85s 275ms/step - loss: 0.0020
# Epoch 9/10
# 309/309 [==============================] - 75s 242ms/step - loss: 0.0011
# Epoch 10/10
# 309/309 [==============================] - 78s 251ms/step - loss: 0.0011

# %%
history1 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 62s 201ms/step - loss: 0.0010
# Epoch 2/10
# 309/309 [==============================] - 62s 199ms/step - loss: 0.0012
# Epoch 3/10
# 309/309 [==============================] - 62s 202ms/step - loss: 7.9981e-04
# Epoch 4/10
# 309/309 [==============================] - 62s 201ms/step - loss: 7.3407e-042s - loss
# Epoch 5/10
# 309/309 [==============================] - 61s 198ms/step - loss: 7.4086e-04
# Epoch 6/10
# 309/309 [==============================] - 73s 237ms/step - loss: 6.4886e-04
# Epoch 7/10
# 309/309 [==============================] - 80s 260ms/step - loss: 6.0326e-04
# Epoch 8/10
# 309/309 [==============================] - 77s 250ms/step - loss: 7.8662e-04
# Epoch 9/10
# 309/309 [==============================] - 67s 216ms/step - loss: 5.7805e-04
# Epoch 10/10
# 309/309 [==============================] - 70s 227ms/step - loss: 5.9948e-04 9s - los

# %%
history2 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 78s 251ms/step - loss: 8.2852e-04
# Epoch 2/10
# 309/309 [==============================] - 80s 258ms/step - loss: 7.2114e-04
# Epoch 3/10
# 309/309 [==============================] - 80s 258ms/step - loss: 4.5869e-04
# Epoch 4/10
# 309/309 [==============================] - 76s 247ms/step - loss: 4.5663e-04
# Epoch 5/10
# 309/309 [==============================] - 76s 244ms/step - loss: 3.5735e-04
# Epoch 6/10
# 309/309 [==============================] - 70s 227ms/step - loss: 6.8016e-04
# Epoch 7/10
# 309/309 [==============================] - 77s 248ms/step - loss: 3.2755e-04
# Epoch 8/10
# 309/309 [==============================] - 75s 244ms/step - loss: 3.2908e-04
# Epoch 9/10
# 309/309 [==============================] - 54s 175ms/step - loss: 3.6131e-04
# Epoch 10/10
# 309/309 [==============================] - 54s 174ms/step - loss: 3.2328e-04

# %%
history3 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 54s 174ms/step - loss: 3.2243e-04
# Epoch 2/10
# 309/309 [==============================] - 53s 173ms/step - loss: 7.2143e-04
# Epoch 3/10
# 309/309 [==============================] - 68s 219ms/step - loss: 2.9254e-04
# Epoch 4/10
# 309/309 [==============================] - 65s 209ms/step - loss: 2.8944e-041s - loss: 2.9
# Epoch 5/10
# 309/309 [==============================] - 66s 212ms/step - loss: 3.3375e-04
# Epoch 6/10
# 309/309 [==============================] - 78s 252ms/step - loss: 3.5800e-04
# Epoch 7/10
# 309/309 [==============================] - 79s 255ms/step - loss: 3.5747e-04
# Epoch 8/10
# 309/309 [==============================] - 78s 254ms/step - loss: 2.4944e-04
# Epoch 9/10
# 309/309 [==============================] - 78s 253ms/step - loss: 2.4735e-04
# Epoch 10/10
# 309/309 [==============================] - 79s 255ms/step - loss: 5.1783e-04

# %%
history4 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 80s 257ms/step - loss: 3.9368e-04
# Epoch 2/10
# 309/309 [==============================] - 81s 261ms/step - loss: 2.5615e-04
# Epoch 3/10
# 309/309 [==============================] - 78s 251ms/step - loss: 2.5179e-04
# Epoch 4/10
# 309/309 [==============================] - 82s 264ms/step - loss: 3.0717e-04
# Epoch 5/10
# 309/309 [==============================] - 82s 267ms/step - loss: 4.0889e-04
# Epoch 6/10
# 309/309 [==============================] - 67s 218ms/step - loss: 3.3558e-04
# Epoch 7/10
# 309/309 [==============================] - 68s 219ms/step - loss: 2.4437e-04
# Epoch 8/10
# 309/309 [==============================] - 68s 221ms/step - loss: 3.6834e-04
# Epoch 9/10
# 309/309 [==============================] - 69s 223ms/step - loss: 4.0291e-04
# Epoch 10/10
# 309/309 [==============================] - 69s 222ms/step - loss: 2.8059e-04

# %%
history5 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 73s 237ms/step - loss: 3.0378e-04
# Epoch 2/10
# 309/309 [==============================] - 87s 280ms/step - loss: 2.8934e-045s
# Epoch 3/10
# 309/309 [==============================] - 82s 266ms/step - loss: 3.5044e-04
# Epoch 4/10
# 309/309 [==============================] - 65s 211ms/step - loss: 3.0888e-04
# Epoch 5/10
# 309/309 [==============================] - 58s 187ms/step - loss: 3.8395e-041s - loss: 3
# Epoch 6/10
# 309/309 [==============================] - 68s 219ms/step - loss: 2.4867e-04
# Epoch 7/10
# 309/309 [==============================] - 57s 186ms/step - loss: 2.5057e-04 3s
# Epoch 8/10
# 309/309 [==============================] - 57s 183ms/step - loss: 2.7166e-04: 3s
# Epoch 9/10
# 309/309 [==============================] - 56s 182ms/step - loss: 3.3603e-040s - loss: 3.3928e
# Epoch 10/10
# 309/309 [==============================] - 56s 182ms/step - loss: 2.8538e-04

# %%
history6 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 62s 201ms/step - loss: 4.9595e-04
# Epoch 2/10
# 309/309 [==============================] - 64s 206ms/step - loss: 3.3655e-04
# Epoch 3/10
# 309/309 [==============================] - 81s 262ms/step - loss: 2.1993e-04
# Epoch 4/10
# 309/309 [==============================] - 65s 211ms/step - loss: 2.4024e-04
# Epoch 5/10
# 309/309 [==============================] - 65s 211ms/step - loss: 3.6599e-04
# Epoch 6/10
# 309/309 [==============================] - 78s 254ms/step - loss: 2.4489e-043s - loss
# Epoch 7/10
# 309/309 [==============================] - 78s 253ms/step - loss: 5.4568e-04
# Epoch 8/10
# 309/309 [==============================] - 84s 270ms/step - loss: 2.4474e-04
# Epoch 9/10
# 309/309 [==============================] - 82s 264ms/step - loss: 2.1585e-04
# Epoch 10/10
# 309/309 [==============================] - 81s 262ms/step - loss: 2.5111e-04

# %%
pred_list = []
batch = train[-n_input:].reshape((1, n_input, n_features))
for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
add_dates = [df.index[-1] + DateOffset(months=x) for x in range(0,51) ]
future_dates = pd.DataFrame(index=add_dates[1:],columns=df.columns)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=future_dates[-n_input:].index, columns=['Prediction'])
df_proj = pd.concat([df,df_predict], axis=1)

# %%
plot_data = [
    go.Scatter(
        x=df_proj.index,
        y=df_proj['close'],
        name='actual'
    ),
    go.Scatter(
        x=df_proj.index,
        y=df_proj['Prediction'],
        name='prediction'
    )
]
plot_layout = go.Layout(
        title='LiteCoin Prediction'
    )
fig = go.Figure(data=plot_data, layout=plot_layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="65edc4ba-f900-42ee-b820-ce09c2e714ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65edc4ba-f900-42ee-b820-ce09c2e714ff")) {
#                     Plotly.newPlot(
#                         '65edc4ba-f900-42ee-b820-ce09c2e714ff',
# ...

# %%
plot_data = [
    go.Scatter(
        x=df_proj.index,
        y=df_proj['close'],
        name='actual'
    ),
    go.Scatter(
        x=df_proj.index,
        y=df_proj['Prediction'],
        name='prediction'
    )
]
plot_layout = go.Layout(
        title='LiteCoin Prediction'
    )
fig = go.Figure(data=plot_data, layout=plot_layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="77e6f976-6a9f-4367-a33c-1af65fb495e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("77e6f976-6a9f-4367-a33c-1af65fb495e8")) {
#                     Plotly.newPlot(
#                         '77e6f976-6a9f-4367-a33c-1af65fb495e8',
# ...

# %%
history7 = model.fit_generator(generator,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 309/309 [==============================] - 63s 204ms/step - loss: 2.3020e-04
# Epoch 2/10
# 309/309 [==============================] - 62s 202ms/step - loss: 4.7199e-04- ETA: 0s - loss: 4.7630e
# Epoch 3/10
# 309/309 [==============================] - 61s 198ms/step - loss: 2.4843e-04
# Epoch 4/10
# 309/309 [==============================] - 58s 188ms/step - loss: 2.4122e-04
# Epoch 5/10
# 309/309 [==============================] - 62s 200ms/step - loss: 2.8094e-04
# Epoch 6/10
# 309/309 [==============================] - 57s 184ms/step - loss: 2.3398e-04
# Epoch 7/10
# 309/309 [==============================] - 57s 185ms/step - loss: 2.9988e-044s - loss: 2.9145e-0 - ETA
# Epoch 8/10
# 309/309 [==============================] - 60s 193ms/step - loss: 2.2743e-04
# Epoch 9/10
# 309/309 [==============================] - 59s 191ms/step - loss: 2.4911e-04
# Epoch 10/10
# 309/309 [==============================] - 67s 218ms/step - loss: 2.9529e-04

# %%
plot_data = [
    go.Scatter(
        x=df_proj.index,
        y=df_proj['close'],
        name='actual'
    ),
    go.Scatter(
        x=df_proj.index,
        y=df_proj['Prediction'],
        name='prediction'
    )
]
plot_layout = go.Layout(
        title='LiteCoin Prediction'
    )
fig = go.Figure(data=plot_data, layout=plot_layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="134ec027-8846-473c-b9bb-7a1fbf834c0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("134ec027-8846-473c-b9bb-7a1fbf834c0d")) {
#                     Plotly.newPlot(
#                         '134ec027-8846-473c-b9bb-7a1fbf834c0d',
# ...
